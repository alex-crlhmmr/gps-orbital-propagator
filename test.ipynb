# %%
import pandas as pd
import numpy as np
from pyproj import Transformer
from scipy.spatial import KDTree
import plotly.graph_objs as go

# Step 1: Load the satellite data from the .gmd file
file_path = "path_to_your_file.gmd"  # Replace with your actual file path
columns = ['Timestamp', 'MeasurementType', 'SatelliteID', 'AdditionalID', 'X', 'Y', 'Z']
df = pd.read_csv(file_path, sep='\s+', names=columns)

# Step 2: Convert X, Y, Z from kilometers to meters
df[['X', 'Y', 'Z']] = df[['X', 'Y', 'Z']] * 1000  # Ensure correct scaling to meters

# Step 3: Convert GPS timestamp to seconds (assume fractional days)
df['Timestamp'] = (df['Timestamp'] - df['Timestamp'].min()) * 86400  # Days to seconds

# Step 4: Group points by space-time proximity
spatial_threshold = 10000  # 10 km in meters
time_threshold = 30  # 30 seconds

df = df.sort_values('Timestamp').reset_index(drop=True)
points = df[['X', 'Y', 'Z']].values
tree = KDTree(points)

groups = []
visited = set()

for i in range(len(df)):
    if i not in visited:
        group = [i]
        visited.add(i)

        for j in range(i + 1, len(df)):
            if j not in visited:
                if np.linalg.norm(points[i] - points[j]) <= spatial_threshold:
                    if abs(df.iloc[j]['Timestamp'] - df.iloc[group[-1]]['Timestamp']) <= time_threshold:
                        group.append(j)
                        visited.add(j)

        groups.append(group)

# Step 5: Create Earth sphere
theta = np.linspace(0, np.pi, 50)
phi = np.linspace(0, 2 * np.pi, 50)
theta, phi = np.meshgrid(theta, phi)

earth_radius = 6371e3  # Earth's mean radius in meters
x_sphere = earth_radius * np.sin(theta) * np.cos(phi)
y_sphere = earth_radius * np.sin(theta) * np.sin(phi)
z_sphere = earth_radius * np.cos(theta)

earth = go.Surface(
    x=x_sphere, y=y_sphere, z=z_sphere,
    opacity=0.5, colorscale='Blues', showscale=False, name='Earth'
)

# Step 6: Create frames for animation
frames = [
    go.Frame(
        data=[go.Scatter3d(
            x=df.iloc[group]['X'], y=df.iloc[group]['Y'], z=df.iloc[group]['Z'],
            mode='markers',  # Only markers, no lines
            marker=dict(size=5, color='red', opacity=0.8),
            name=f"Arc {i}"
        )],
        name=f"Arc {i}"
    )
    for i, group in enumerate(groups)
]

# Step 7: Layout configuration with the Earth sphere visible at all times
layout = go.Layout(
    scene=dict(
        xaxis=dict(title='X (meters)', range=[-7e6, 7e6]),
        yaxis=dict(title='Y (meters)', range=[-7e6, 7e6]),
        zaxis=dict(title='Z (meters)', range=[-7e6, 7e6]),
        aspectmode='data'
    ),
    title='Satellite Arcs with Disjoint Groups on Earth Sphere',
    updatemenus=[dict(
        type="buttons",
        showactive=False,
        buttons=[dict(
            label="Play", method="animate",
            args=[None, dict(frame=dict(duration=1000, redraw=True), fromcurrent=True, mode='immediate')]
        )]
    )],
    sliders=[dict(
        steps=[dict(method='animate', args=[[f"Arc {i}"], dict(mode='immediate')], label=f"Arc {i}")
               for i in range(len(groups))],
        active=0,
        x=0.1, y=0, len=0.8
    )]
)

# Step 8: Create the figure with the Earth sphere and frames
fig = go.Figure(data=[earth], layout=layout, frames=frames)

# Step 9: Save and open the plot
fig.write_html("satellite_arcs_no_linkage_corrected.html", auto_open=True)

# %%
import pandas as pd
import numpy as np
from pyproj import Transformer
from scipy.spatial import KDTree
import plotly.graph_objs as go

# Step 1: Load the satellite data from the .gmd file
file_path = "gmat_gps.gmd"  # Replace with your actual file path
columns = ['Timestamp', 'MeasurementType', 'SatelliteID', 'AdditionalID', 'X', 'Y', 'Z']
df = pd.read_csv(file_path, sep='\s+', names=columns)

# Step 2: Convert X, Y, Z from kilometers to meters
df[['X', 'Y', 'Z']] = df[['X', 'Y', 'Z']] * 1000  # Ensure correct scaling to meters

# Step 3: Convert GPS timestamp to seconds (assume fractional days)
df['Timestamp'] = (df['Timestamp'] - df['Timestamp'].min()) * 86400  # Days to seconds

# Step 4: Group points by space-time proximity
spatial_threshold = 10000*300  # 10 km in meters
time_threshold = 3600*8  # 30 seconds

df = df.sort_values('Timestamp').reset_index(drop=True)
points = df[['X', 'Y', 'Z']].values
tree = KDTree(points)

groups = []
visited = set()

for i in range(len(df)):
    if i not in visited:
        group = [i]
        visited.add(i)

        for j in range(i + 1, len(df)):
            if j not in visited:
                if np.linalg.norm(points[i] - points[j]) <= spatial_threshold:
                    if abs(df.iloc[j]['Timestamp'] - df.iloc[group[-1]]['Timestamp']) <= time_threshold:
                        group.append(j)
                        visited.add(j)

        groups.append(group)

# Step 5: Create Earth sphere
theta = np.linspace(0, np.pi, 50)
phi = np.linspace(0, 2 * np.pi, 50)
theta, phi = np.meshgrid(theta, phi)

earth_radius = 6371e3  # Earth's mean radius in meters
x_sphere = earth_radius * np.sin(theta) * np.cos(phi)
y_sphere = earth_radius * np.sin(theta) * np.sin(phi)
z_sphere = earth_radius * np.cos(theta)

earth = go.Surface(
    x=x_sphere, y=y_sphere, z=z_sphere,
    opacity=0.5, colorscale='Blues', showscale=False, name='Earth'
)

# Step 6: Create frames for animation
frames = [
    go.Frame(
        data=[go.Scatter3d(
            x=df.iloc[group]['X'], y=df.iloc[group]['Y'], z=df.iloc[group]['Z'],
            mode='markers',  # Only markers, no lines
            marker=dict(size=5, color='red', opacity=0.8),
            name=f"Arc {i}"
        )],
        name=f"Arc {i}"
    )
    for i, group in enumerate(groups)
]

# Step 7: Layout configuration with the Earth sphere visible at all times
layout = go.Layout(
    scene=dict(
        xaxis=dict(title='X (meters)', range=[-7e6, 7e6]),
        yaxis=dict(title='Y (meters)', range=[-7e6, 7e6]),
        zaxis=dict(title='Z (meters)', range=[-7e6, 7e6]),
        aspectmode='data'
    ),
    title='Satellite Arcs with Disjoint Groups on Earth Sphere',
    updatemenus=[dict(
        type="buttons",
        showactive=False,
        buttons=[dict(
            label="Play", method="animate",
            args=[None, dict(frame=dict(duration=1000, redraw=True), fromcurrent=True, mode='immediate')]
        )]
    )],
    sliders=[dict(
        steps=[dict(method='animate', args=[[f"Arc {i}"], dict(mode='immediate')], label=f"Arc {i}")
               for i in range(len(groups))],
        active=0,
        x=0.1, y=0, len=0.8
    )]
)

# Step 8: Create the figure with the Earth sphere and frames
fig = go.Figure(data=[earth], layout=layout, frames=frames)

# Step 9: Save and open the plot
fig.write_html("satellite_arcs_no_linkage_corrected.html", auto_open=True)

# %%
import pandas as pd
import numpy as np
from pyproj import Transformer
from scipy.spatial import KDTree
import plotly.graph_objs as go

# Step 1: Load the satellite data from the .gmd file
file_path = "gmat_gps.gmd"  # Replace with your actual file path
columns = ['Timestamp', 'MeasurementType', 'SatelliteID', 'AdditionalID', 'X', 'Y', 'Z']
df = pd.read_csv(file_path, sep='\s+', names=columns)

# Step 2: Convert X, Y, Z from kilometers to meters
df[['X', 'Y', 'Z']] = df[['X', 'Y', 'Z']] * 1000  # Ensure correct scaling to meters

# Step 3: Convert GPS timestamp to seconds (assume fractional days)
df['Timestamp'] = (df['Timestamp'] - df['Timestamp'].min()) * 86400  # Convert days to seconds

# Step 4: Time-first grouping: Group points by time windows first, then by spatial proximity
time_threshold = 3600*9  # 1 hour threshold in seconds
spatial_threshold = 1000*5000  # 10 km threshold in meters

# Step 4.1: Group points by time (first priority)
time_groups = []
visited_time = set()

for i in range(len(df)):
    if i not in visited_time:
        # Create a new time-based group starting with point 'i'
        current_group = [i]
        visited_time.add(i)

        # Add all points within the time threshold
        for j in range(i + 1, len(df)):
            if j not in visited_time and abs(df.iloc[j]['Timestamp'] - df.iloc[i]['Timestamp']) <= time_threshold:
                current_group.append(j)
                visited_time.add(j)

        time_groups.append(current_group)

# Step 4.2: Within each time group, further group by spatial proximity
final_groups = []
for time_group in time_groups:
    group_points = df.iloc[time_group][['X', 'Y', 'Z']].values
    tree = KDTree(group_points)

    visited_space = set()
    for i, point in enumerate(group_points):
        if i not in visited_space:
            # Create a spatial group starting with the current point
            spatial_group = [time_group[i]]
            visited_space.add(i)

            # Find all nearby points within the spatial threshold
            neighbors = tree.query_ball_point(point, r=spatial_threshold)
            for neighbor in neighbors:
                if neighbor not in visited_space:
                    spatial_group.append(time_group[neighbor])
                    visited_space.add(neighbor)

            final_groups.append(spatial_group)


final_groups = time_group

# Step 5: Create Earth sphere
theta = np.linspace(0, np.pi, 50)
phi = np.linspace(0, 2 * np.pi, 50)
theta, phi = np.meshgrid(theta, phi)

earth_radius = 6371e3  # Earth's mean radius in meters
x_sphere = earth_radius * np.sin(theta) * np.cos(phi)
y_sphere = earth_radius * np.sin(theta) * np.sin(phi)
z_sphere = earth_radius * np.cos(theta)

earth = go.Surface(
    x=x_sphere, y=y_sphere, z=z_sphere,
    opacity=0.5, colorscale='Blues', showscale=False, name='Earth'
)

# Step 6: Create frames for animation (no linkage between arcs)
frames = [
    go.Frame(
        data=[go.Scatter3d(
            x=df.iloc[group]['X'], y=df.iloc[group]['Y'], z=df.iloc[group]['Z'],
            mode='markers',  # Only markers, no lines
            marker=dict(size=5, color='red', opacity=0.8),
            name=f"Arc {i}"
        )],
        name=f"Arc {i}"
    )
    for i, group in enumerate(final_groups)
]

# Step 7: Layout configuration with the Earth sphere visible at all times
layout = go.Layout(
    scene=dict(
        xaxis=dict(title='X (meters)', range=[-7e6, 7e6]),
        yaxis=dict(title='Y (meters)', range=[-7e6, 7e6]),
        zaxis=dict(title='Z (meters)', range=[-7e6, 7e6]),
        aspectmode='data'
    ),
    title='Satellite Arcs Grouped by Time and Space on Earth Sphere',
    updatemenus=[dict(
        type="buttons",
        showactive=False,
        buttons=[dict(
            label="Play", method="animate",
            args=[None, dict(frame=dict(duration=1000, redraw=True), fromcurrent=True, mode='immediate')]
        )]
    )],
    sliders=[dict(
        steps=[dict(method='animate', args=[[f"Arc {i}"], dict(mode='immediate')], label=f"Arc {i}")
               for i in range(len(final_groups))],
        active=0,
        x=0.1, y=0, len=0.8
    )]
)

# Step 8: Create the figure with the Earth sphere and frames
fig = go.Figure(data=[earth], layout=layout, frames=frames)

# Step 9: Save and open the plot
fig.write_html("satellite_arcs_time_first.html", auto_open=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 81
#      75 earth = go.Surface(
#      76     x=x_sphere, y=y_sphere, z=z_sphere,
#      77     opacity=0.5, colorscale='Blues', showscale=False, name='Earth'
#      78 )
#      80 # Step 6: Create frames for animation (no linkage between arcs)
# ---> 81 frames = [
#      82     go.Frame(
#      83         data=[go.Scatter3d(
#      84             x=df.iloc[group]['X'], y=df.iloc[group]['Y'], z=df.iloc[group]['Z'],
#      85             mode='markers',  # Only markers, no lines
#      86             marker=dict(size=5, color='red', opacity=0.8),
#      87             name=f"Arc {i}"
#      88         )],
#      89         name=f"Arc {i}"
#      90     )
#      91     for i, group in enumerate(final_groups)
#      92 ]
#      94 # Step 7: Layout configuration with the Earth sphere visible at all times
#      95 layout = go.Layout(
#      96     scene=dict(
#      97         xaxis=dict(title='X (meters)', range=[-7e6, 7e6]),
#    (...)
#     116     )]
#     117 )
#
# Cell In[7], line 83, in <listcomp>(.0)
#      75 earth = go.Surface(
#      76     x=x_sphere, y=y_sphere, z=z_sphere,
#      77     opacity=0.5, colorscale='Blues', showscale=False, name='Earth'
#      78 )
#      80 # Step 6: Create frames for animation (no linkage between arcs)
#      81 frames = [
#      82     go.Frame(
# ---> 83         data=[go.Scatter3d(
#      84             x=df.iloc[group]['X'], y=df.iloc[group]['Y'], z=df.iloc[group]['Z'],
#      85             mode='markers',  # Only markers, no lines
#      86             marker=dict(size=5, color='red', opacity=0.8),
#      87             name=f"Arc {i}"
#      88         )],
#      89         name=f"Arc {i}"
#      90     )
#      91     for i, group in enumerate(final_groups)
#      92 ]
#      94 # Step 7: Layout configuration with the Earth sphere visible at all times
#      95 layout = go.Layout(
#      96     scene=dict(
#      97         xaxis=dict(title='X (meters)', range=[-7e6, 7e6]),
#    (...)
#     116     )]
#     117 )
#
# File c:\Users\carlh\anaconda3\envs\gps\lib\site-packages\plotly\graph_objs\_scatter3d.py:2785, in Scatter3d.__init__(self, arg, connectgaps, customdata, customdatasrc, error_x, error_y, error_z, hoverinfo, hoverinfosrc, hoverlabel, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, legend, legendgroup, legendgrouptitle, legendrank, legendwidth, line, marker, meta, metasrc, mode, name, opacity, projection, scene, showlegend, stream, surfaceaxis, surfacecolor, text, textfont, textposition, textpositionsrc, textsrc, texttemplate, texttemplatesrc, uid, uirevision, visible, x, xcalendar, xhoverformat, xsrc, y, ycalendar, yhoverformat, ysrc, z, zcalendar, zhoverformat, zsrc, **kwargs)
#    2783 _v = x if x is not None else _v
#    2784 if _v is not None:
# -> 2785     self["x"] = _v
#    2786 _v = arg.pop("xcalendar", None)
#    2787 _v = xcalendar if xcalendar is not None else _v
#
# File c:\Users\carlh\anaconda3\envs\gps\lib\site-packages\plotly\basedatatypes.py:4868, in BasePlotlyType.__setitem__(self, prop, value)
#    4864         self._set_array_prop(prop, value)
#    4866     # ### Handle simple property ###
#    4867     else:
# -> 4868         self._set_prop(prop, value)
#    4869 else:
#    4870     # Make sure properties dict is initialized
#    4871     self._init_props()
#
# File c:\Users\carlh\anaconda3\envs\gps\lib\site-packages\plotly\basedatatypes.py:5212, in BasePlotlyType._set_prop(self, prop, val)
#    5210         return
#    5211     else:
# -> 5212         raise err
#    5214 # val is None
#    5215 # -----------
#    5216 if val is None:
#    5217     # Check if we should send null update
#
# File c:\Users\carlh\anaconda3\envs\gps\lib\site-packages\plotly\basedatatypes.py:5207, in BasePlotlyType._set_prop(self, prop, val)
#    5204 validator = self._get_validator(prop)
#    5206 try:
# -> 5207     val = validator.validate_coerce(val)
#    5208 except ValueError as err:
#    5209     if self._skip_invalid:
#
# File c:\Users\carlh\anaconda3\envs\gps\lib\site-packages\_plotly_utils\basevalidators.py:412, in DataArrayValidator.validate_coerce(self, v)
#     410     v = to_scalar_or_list(v)
#     411 else:
# --> 412     self.raise_invalid_val(v)
#     413 return v
#
# File c:\Users\carlh\anaconda3\envs\gps\lib\site-packages\_plotly_utils\basevalidators.py:296, in BaseValidator.raise_invalid_val(self, v, inds)
#     293             for i in inds:
#     294                 name += "[" + str(i) + "]"
# --> 296         raise ValueError(
#     297             """
#     298     Invalid value of type {typ} received for the '{name}' property of {pname}
#     299         Received value: {v}
#     300
#     301 {valid_clr_desc}""".format(
#     302                 name=name,
#     303                 pname=self.parent_name,
#     304                 typ=type_str(v),
#     305                 v=repr(v),
#     306                 valid_clr_desc=self.description(),
#     307             )
#     308         )
#
# ValueError:
#     Invalid value of type 'numpy.float64' received for the 'x' property of scatter3d
#         Received value: -3458168.1925995667
#
#     The 'x' property is an array that may be specified as a tuple,
#     list, numpy array, or pandas Series

# %%
import pandas as pd
import numpy as np
from pyproj import Transformer
import plotly.graph_objs as go

# Step 1: Load the satellite data from the .gmd file
file_path = "gmat_gps.gmd"  # Replace with your actual file path
columns = ['Timestamp', 'MeasurementType', 'SatelliteID', 'AdditionalID', 'X', 'Y', 'Z']
df = pd.read_csv(file_path, sep='\s+', names=columns)

# Step 2: Convert X, Y, Z from kilometers to meters
df[['X', 'Y', 'Z']] = df[['X', 'Y', 'Z']] * 1000  # Scale to meters

# Step 3: Convert GPS timestamp to seconds (assume fractional days)
df['Timestamp'] = (df['Timestamp'] - df['Timestamp'].min()) * 86400  # Convert days to seconds

# Step 4: Group points by time windows only
time_threshold = 3600*2  # 1 hour in seconds

# Initialize groups
groups = []
visited = set()

# Group by time
for i in range(len(df)):
    if i not in visited:
        # Create a new time-based group
        group = [i]
        visited.add(i)

        # Add all points within the time threshold
        for j in range(i + 1, len(df)):
            if j not in visited and abs(df.iloc[j]['Timestamp'] - df.iloc[i]['Timestamp']) <= time_threshold:
                group.append(j)
                visited.add(j)

        groups.append(group)

# Step 5: Create Earth sphere
theta = np.linspace(0, np.pi, 50)
phi = np.linspace(0, 2 * np.pi, 50)
theta, phi = np.meshgrid(theta, phi)

earth_radius = 6371e3  # Earth's mean radius in meters
x_sphere = earth_radius * np.sin(theta) * np.cos(phi)
y_sphere = earth_radius * np.sin(theta) * np.sin(phi)
z_sphere = earth_radius * np.cos(theta)

earth = go.Surface(
    x=x_sphere, y=y_sphere, z=z_sphere,
    opacity=0.5, colorscale='Blues', showscale=False, name='Earth'
)

# Step 6: Create frames for animation (no linkage between time groups)
frames = [
    go.Frame(
        data=[go.Scatter3d(
            x=df.iloc[group]['X'], y=df.iloc[group]['Y'], z=df.iloc[group]['Z'],
            mode='markers',  # Markers only, no lines
            marker=dict(size=5, color='red', opacity=0.8),
            name=f"Time Group {i}"
        )],
        name=f"Time Group {i}"
    )
    for i, group in enumerate(groups)
]

# Step 7: Layout configuration with Earth sphere visible at all times
layout = go.Layout(
    scene=dict(
        xaxis=dict(title='X (meters)', range=[-7e6, 7e6]),
        yaxis=dict(title='Y (meters)', range=[-7e6, 7e6]),
        zaxis=dict(title='Z (meters)', range=[-7e6, 7e6]),
        aspectmode='data'
    ),
    title='Satellite Points Grouped by Time on Earth Sphere',
    updatemenus=[dict(
        type="buttons",
        showactive=False,
        buttons=[dict(
            label="Play", method="animate",
            args=[None, dict(frame=dict(duration=1000, redraw=True), fromcurrent=True, mode='immediate')]
        )]
    )],
    sliders=[dict(
        steps=[dict(method='animate', args=[[f"Time Group {i}"], dict(mode='immediate')], label=f"Group {i}")
               for i in range(len(groups))],
        active=0,
        x=0.1, y=0, len=0.8
    )]
)

# Step 8: Create the figure with the Earth sphere and frames
fig = go.Figure(data=[earth], layout=layout, frames=frames)

# Step 9: Save and open the plot
fig.write_html("satellite_time_grouped.html", auto_open=True)

# %%
import pandas as pd
import numpy as np
#from pyproj import Transformer
import plotly.graph_objs as go

# Step 1: Load the satellite data from the .gmd file
file_path = "gmat_gps.gmd"  # Replace with your actual file path
columns = ['Timestamp', 'MeasurementType', 'SatelliteID', 'AdditionalID', 'X', 'Y', 'Z']
df = pd.read_csv(file_path, sep='\s+', names=columns)

# Step 2: Convert X, Y, Z from kilometers to meters
df[['X', 'Y', 'Z']] = df[['X', 'Y', 'Z']] * 1000  # Scale to meters

# Step 3: Convert GPS timestamp to seconds (assume fractional days)
df['Timestamp'] = (df['Timestamp'] - df['Timestamp'].min()) * 86400  # Convert days to seconds

# Step 4: Group points by time window (1-hour threshold)
time_threshold = 3600  # 1 hour in seconds

groups = []
visited = set()

for i in range(len(df)):
    if i not in visited:
        group = [i]
        visited.add(i)

        for j in range(i + 1, len(df)):
            if j not in visited and abs(df.iloc[j]['Timestamp'] - df.iloc[i]['Timestamp']) <= time_threshold:
                group.append(j)
                visited.add(j)

        groups.append(group)

# Step 5: Define a function to project points onto the Earth sphere surface
def project_to_ecef(x, y, z, radius=6371e3):
    norm = np.sqrt(x**2 + y**2 + z**2)
    return (x / norm) * radius, (y / norm) * radius, (z / norm) * radius

# Step 6: Create the Earth sphere for reference
theta = np.linspace(0, np.pi, 50)
phi = np.linspace(0, 2 * np.pi, 50)
theta, phi = np.meshgrid(theta, phi)

earth_radius = 6371e3  # Earth's mean radius in meters
x_sphere = earth_radius * np.sin(theta) * np.cos(phi)
y_sphere = earth_radius * np.sin(theta) * np.sin(phi)
z_sphere = earth_radius * np.cos(theta)

earth = go.Surface(
    x=x_sphere, y=y_sphere, z=z_sphere,
    opacity=0.3, colorscale='Blues', showscale=False, name='Earth'
)

# Step 7: Create frames for animation with projections on the sphere
frames = []

for i, group in enumerate(groups):
    # Original points
    group_data = df.iloc[group]
    x, y, z = group_data['X'], group_data['Y'], group_data['Z']

    # Projected points on the ECEF sphere
    proj_x, proj_y, proj_z = project_to_ecef(x, y, z)

    # Create a frame with both original and projected points
    frame_data = [
        go.Scatter3d(
            x=x, y=y, z=z,
            mode='markers',
            marker=dict(size=5, color='red', opacity=0.8),
            name=f"Original Group {i}"
        ),
        go.Scatter3d(
            x=proj_x, y=proj_y, z=proj_z,
            mode='markers',
            marker=dict(size=4, color='green', opacity=0.6),
            name=f"Projected Group {i}"
        )
    ]

    frames.append(go.Frame(data=frame_data, name=f"Group {i}"))

# Step 8: Layout configuration with Earth sphere visible at all times
layout = go.Layout(
    scene=dict(
        xaxis=dict(title='X (meters)', range=[-7e6, 7e6]),
        yaxis=dict(title='Y (meters)', range=[-7e6, 7e6]),
        zaxis=dict(title='Z (meters)', range=[-7e6, 7e6]),
        aspectmode='data'
    ),
    title='Satellite Points and ECEF Projections on Earth Sphere',
    updatemenus=[dict(
        type="buttons",
        showactive=False,
        buttons=[dict(
            label="Play", method="animate",
            args=[None, dict(frame=dict(duration=1000, redraw=True), fromcurrent=True, mode='immediate')]
        )]
    )],
    sliders=[dict(
        steps=[dict(method='animate', args=[[f"Group {i}"], dict(mode='immediate')], label=f"Group {i}")
               for i in range(len(groups))],
        active=0,
        x=0.1, y=0, len=0.8
    )]
)

# Step 9: Create the figure with the Earth sphere and frames
fig = go.Figure(data=[earth], layout=layout, frames=frames)

# Step 10: Save and open the plot
fig.write_html("satellite_ecef_projection.html", auto_open=True)

# %%
import pandas as pd
import numpy as np
#from pyproj import Transformer
import plotly.graph_objs as go

# Step 1: Load the satellite data from the .gmd file
file_path = "gmat_gps.gmd"  # Replace with your actual file path
columns = ['Timestamp', 'MeasurementType', 'SatelliteID', 'AdditionalID', 'X', 'Y', 'Z']
df = pd.read_csv(file_path, sep='\s+', names=columns)

# Step 2: Convert X, Y, Z from kilometers to meters
df[['X', 'Y', 'Z']] = df[['X', 'Y', 'Z']] * 1000  # Scale to meters

# Step 3: Convert GPS timestamp to seconds (assuming fractional days)
df['Timestamp'] = (df['Timestamp'] - df['Timestamp'].min()) * 86400  # Convert days to seconds

# Step 4: Group points by time window (1-hour threshold)
time_threshold = 3600  # 1 hour in seconds

groups = []
visited = set()

for i in range(len(df)):
    if i not in visited:
        group = [i]
        visited.add(i)

        for j in range(i + 1, len(df)):
            if j not in visited and abs(df.iloc[j]['Timestamp'] - df.iloc[i]['Timestamp']) <= time_threshold:
                group.append(j)
                visited.add(j)

        groups.append(group)

# Step 5: Define a function to project points onto the Earth sphere surface
def project_to_ecef(x, y, z, radius=6371e3):
    norm = np.sqrt(x**2 + y**2 + z**2)
    return (x / norm) * radius, (y / norm) * radius, (z / norm) * radius

# Step 6: Create the Earth sphere for reference
theta = np.linspace(0, np.pi, 50)
phi = np.linspace(0, 2 * np.pi, 50)
theta, phi = np.meshgrid(theta, phi)

earth_radius = 6371e3  # Earth's mean radius in meters
x_sphere = earth_radius * np.sin(theta) * np.cos(phi)
y_sphere = earth_radius * np.sin(theta) * np.sin(phi)
z_sphere = earth_radius * np.cos(theta)

# Function to generate the Earth sphere for each frame
def get_earth_surface():
    return go.Surface(
        x=x_sphere, y=y_sphere, z=z_sphere,
        opacity=0.3, colorscale='Blues', showscale=False, name='Earth'
    )

# Step 7: Create frames for animation with projections on the sphere
frames = []

for i, group in enumerate(groups):
    # Original points
    group_data = df.iloc[group]
    x, y, z = group_data['X'], group_data['Y'], group_data['Z']

    # Projected points on the ECEF sphere
    proj_x, proj_y, proj_z = project_to_ecef(x, y, z)

    # Create a frame with both original and projected points plus the Earth sphere
    frame_data = [
        get_earth_surface(),  # Add the Earth sphere to each frame
        go.Scatter3d(
            x=x, y=y, z=z,
            mode='markers',
            marker=dict(size=5, color='red', opacity=0.8),
            name=f"Original Group {i}"
        ),
        go.Scatter3d(
            x=proj_x, y=proj_y, z=proj_z,
            mode='markers',
            marker=dict(size=4, color='green', opacity=0.6),
            name=f"Projected Group {i}"
        )
    ]

    frames.append(go.Frame(data=frame_data, name=f"Group {i}"))

# Step 8: Layout configuration with Earth sphere visible at all times
layout = go.Layout(
    scene=dict(
        xaxis=dict(title='X (meters)', range=[-7e6, 7e6]),
        yaxis=dict(title='Y (meters)', range=[-7e6, 7e6]),
        zaxis=dict(title='Z (meters)', range=[-7e6, 7e6]),
        aspectmode='data'
    ),
    title='Satellite Points and ECEF Projections on Earth Sphere',
    updatemenus=[dict(
        type="buttons",
        showactive=False,
        buttons=[dict(
            label="Play", method="animate",
            args=[None, dict(frame=dict(duration=1000, redraw=True), fromcurrent=True, mode='immediate')]
        )]
    )],
    sliders=[dict(
        steps=[dict(method='animate', args=[[f"Group {i}"], dict(mode='immediate')], label=f"Group {i}")
               for i in range(len(groups))],
        active=0,
        x=0.1, y=0, len=0.8
    )]
)

# Step 9: Create the figure with the Earth sphere and frames
fig = go.Figure(data=[get_earth_surface()], layout=layout, frames=frames)

# Step 10: Save and open the plot
fig.write_html("satellite_ecef_projection_with_sphere.html", auto_open=True)

# %%
import pandas as pd
import numpy as np
#from pyproj import Transformer
import plotly.graph_objs as go

# Step 1: Load the satellite data from the .gmd file
file_path = "gmat_gps.gmd"  # Replace with your actual file path
columns = ['Timestamp', 'MeasurementType', 'SatelliteID', 'AdditionalID', 'X', 'Y', 'Z']
df = pd.read_csv(file_path, sep='\s+', names=columns)

# Step 2: Convert X, Y, Z from kilometers to meters
df[['X', 'Y', 'Z']] = df[['X', 'Y', 'Z']] * 1000  # Scale to meters

# Step 3: Convert GPS timestamp to seconds (assuming fractional days)
df['Timestamp'] = (df['Timestamp'] - df['Timestamp'].min()) * 86400  # Convert days to seconds

# Step 4: Group points by time window (1-hour threshold)
time_threshold = 3600  # 1 hour in seconds

groups = []
visited = set()

for i in range(len(df)):
    if i not in visited:
        group = [i]
        visited.add(i)

        for j in range(i + 1, len(df)):
            if j not in visited and abs(df.iloc[j]['Timestamp'] - df.iloc[i]['Timestamp']) <= time_threshold:
                group.append(j)
                visited.add(j)

        groups.append(group)

# Step 5: Define a function to project points onto the Earth sphere surface
def project_to_ecef(x, y, z, radius=6371e3):
    norm = np.sqrt(x**2 + y**2 + z**2)
    return (x / norm) * radius, (y / norm) * radius, (z / norm) * radius

# Step 6: Create the Earth sphere for reference
theta = np.linspace(0, np.pi, 50)
phi = np.linspace(0, 2 * np.pi, 50)
theta, phi = np.meshgrid(theta, phi)

earth_radius = 6371e3  # Earth's mean radius in meters
x_sphere = earth_radius * np.sin(theta) * np.cos(phi)
y_sphere = earth_radius * np.sin(theta) * np.sin(phi)
z_sphere = earth_radius * np.cos(theta)

# Function to generate the Earth sphere for each frame
def get_earth_surface():
    return go.Surface(
        x=x_sphere, y=y_sphere, z=z_sphere,
        opacity=0.3, colorscale='Blues', showscale=False, name='Earth'
    )

# Step 7: Create frames for animation with projections on the sphere
frames = []

for i, group in enumerate(groups):
    # Extract group data
    group_data = df.iloc[group]
    x, y, z = group_data['X'], group_data['Y'], group_data['Z']

    # Projected points on the ECEF sphere
    proj_x, proj_y, proj_z = project_to_ecef(x, y, z)

    # Debugging: Print coordinates to ensure points are loaded correctly
    print(f"Group {i}: Original Points -> {len(x)} points")
    print(f"Group {i}: Projected Points -> {len(proj_x)} points")

    # Create a frame with both original and projected points plus the Earth sphere
    frame_data = [
        get_earth_surface(),  # Add the Earth sphere to each frame
        go.Scatter3d(
            x=x, y=y, z=z,
            mode='markers',
            marker=dict(size=5, color='red', opacity=0.8),
            name=f"Original Group {i}"
        ),
        go.Scatter3d(
            x=proj_x, y=proj_y, z=proj_z,
            mode='markers',
            marker=dict(size=4, color='green', opacity=0.6),
            name=f"Projected Group {i}"
        )
    ]

    frames.append(go.Frame(data=frame_data, name=f"Group {i}"))

# Step 8: Layout configuration with Earth sphere and correct axis ranges
layout = go.Layout(
    scene=dict(
        xaxis=dict(title='X (meters)', range=[-7e6, 7e6]),
        yaxis=dict(title='Y (meters)', range=[-7e6, 7e6]),
        zaxis=dict(title='Z (meters)', range=[-7e6, 7e6]),
        aspectmode='data'
    ),
    title='Satellite Points and ECEF Projections on Earth Sphere',
    updatemenus=[dict(
        type="buttons",
        showactive=False,
        buttons=[dict(
            label="Play", method="animate",
            args=[None, dict(frame=dict(duration=1000, redraw=True), fromcurrent=True, mode='immediate')]
        )]
    )],
    sliders=[dict(
        steps=[dict(method='animate', args=[[f"Group {i}"], dict(mode='immediate')], label=f"Group {i}")
               for i in range(len(groups))],
        active=0,
        x=0.1, y=0, len=0.8
    )]
)

# Step 9: Create the figure with the Earth sphere and frames
fig = go.Figure(data=[get_earth_surface()], layout=layout, frames=frames)

# Step 10: Save and open the plot
fig.write_html("satellite_ecef_projection_debugged.html", auto_open=True)
# Out:
# Group 0: Original Points -> 1 points
# Group 0: Projected Points -> 1 points
# Group 1: Original Points -> 1 points
# Group 1: Projected Points -> 1 points
# Group 2: Original Points -> 1 points
# Group 2: Projected Points -> 1 points
# Group 3: Original Points -> 4 points
# Group 3: Projected Points -> 4 points
# Group 4: Original Points -> 5 points
# Group 4: Projected Points -> 5 points
# Group 5: Original Points -> 1 points
# Group 5: Projected Points -> 1 points
# Group 6: Original Points -> 1 points
# Group 6: Projected Points -> 1 points
# Group 7: Original Points -> 1 points
# Group 7: Projected Points -> 1 points
# Group 8: Original Points -> 5 points
# Group 8: Projected Points -> 5 points
# Group 9: Original Points -> 2 points
# Group 9: Projected Points -> 2 points
# Group 10: Original Points -> 6 points
# Group 10: Projected Points -> 6 points
# Group 11: Original Points -> 2 points
# Group 11: Projected Points -> 2 points
# Group 12: Original Points -> 1 points
# Group 12: Projected Points -> 1 points
# Group 13: Original Points -> 1 points
# Group 13: Projected Points -> 1 points
# Group 14: Original Points -> 3 points
# Group 14: Projected Points -> 3 points
# Group 15: Original Points -> 2 points
# Group 15: Projected Points -> 2 points
# Group 16: Original Points -> 2 points
# Group 16: Projected Points -> 2 points
# Group 17: Original Points -> 2 points
# Group 17: Projected Points -> 2 points
# Group 18: Original Points -> 1 points
# Group 18: Projected Points -> 1 points
# Group 19: Original Points -> 1 points
# Group 19: Projected Points -> 1 points
# Group 20: Original Points -> 4 points
# Group 20: Projected Points -> 4 points
# Group 21: Original Points -> 1 points
# Group 21: Projected Points -> 1 points
# Group 22: Original Points -> 1 points
# Group 22: Projected Points -> 1 points
# Group 23: Original Points -> 4 points
# Group 23: Projected Points -> 4 points
# Group 24: Original Points -> 9 points
# Group 24: Projected Points -> 9 points
# Group 25: Original Points -> 3 points
# Group 25: Projected Points -> 3 points
# Group 26: Original Points -> 4 points
# Group 26: Projected Points -> 4 points
# Group 27: Original Points -> 2 points
# Group 27: Projected Points -> 2 points
# Group 28: Original Points -> 1 points
# Group 28: Projected Points -> 1 points
# Group 29: Original Points -> 3 points
# Group 29: Projected Points -> 3 points
# Group 30: Original Points -> 1 points
# Group 30: Projected Points -> 1 points
# Group 31: Original Points -> 1 points
# Group 31: Projected Points -> 1 points
# Group 32: Original Points -> 6 points
# Group 32: Projected Points -> 6 points
# Group 33: Original Points -> 1 points
# Group 33: Projected Points -> 1 points
# Group 34: Original Points -> 1 points
# Group 34: Projected Points -> 1 points
# Group 35: Original Points -> 1 points
# Group 35: Projected Points -> 1 points
# Group 36: Original Points -> 1 points
# Group 36: Projected Points -> 1 points
# Group 37: Original Points -> 1 points
# Group 37: Projected Points -> 1 points
# Group 38: Original Points -> 2 points
# Group 38: Projected Points -> 2 points
# Group 39: Original Points -> 6 points
# Group 39: Projected Points -> 6 points
# Group 40: Original Points -> 6 points
# Group 40: Projected Points -> 6 points
# Group 41: Original Points -> 2 points
# Group 41: Projected Points -> 2 points
# Group 42: Original Points -> 1 points
# Group 42: Projected Points -> 1 points
# Group 43: Original Points -> 3 points
# Group 43: Projected Points -> 3 points
# Group 44: Original Points -> 1 points
# Group 44: Projected Points -> 1 points
# Group 45: Original Points -> 6 points
# Group 45: Projected Points -> 6 points
# Group 46: Original Points -> 4 points
# Group 46: Projected Points -> 4 points
# Group 47: Original Points -> 9 points
# Group 47: Projected Points -> 9 points
# Group 48: Original Points -> 1 points
# Group 48: Projected Points -> 1 points
# Group 49: Original Points -> 5 points
# Group 49: Projected Points -> 5 points
# Group 50: Original Points -> 5 points
# Group 50: Projected Points -> 5 points
# Group 51: Original Points -> 4 points
# Group 51: Projected Points -> 4 points
# Group 52: Original Points -> 2 points
# Group 52: Projected Points -> 2 points
# Group 53: Original Points -> 10 points
# Group 53: Projected Points -> 10 points
# Group 54: Original Points -> 12 points
# Group 54: Projected Points -> 12 points
# Group 55: Original Points -> 3 points
# Group 55: Projected Points -> 3 points
# Group 56: Original Points -> 4 points
# Group 56: Projected Points -> 4 points
# Group 57: Original Points -> 3 points
# Group 57: Projected Points -> 3 points
# Group 58: Original Points -> 6 points
# Group 58: Projected Points -> 6 points
# Group 59: Original Points -> 9 points
# Group 59: Projected Points -> 9 points
# Group 60: Original Points -> 3 points
# Group 60: Projected Points -> 3 points
# Group 61: Original Points -> 2 points
# Group 61: Projected Points -> 2 points
# Group 62: Original Points -> 1 points
# Group 62: Projected Points -> 1 points
# Group 63: Original Points -> 7 points
# Group 63: Projected Points -> 7 points
# Group 64: Original Points -> 6 points
# Group 64: Projected Points -> 6 points
# Group 65: Original Points -> 6 points
# Group 65: Projected Points -> 6 points
# Group 66: Original Points -> 14 points
# Group 66: Projected Points -> 14 points
# Group 67: Original Points -> 13 points
# Group 67: Projected Points -> 13 points
# Group 68: Original Points -> 13 points
# Group 68: Projected Points -> 13 points
# Group 69: Original Points -> 11 points
# Group 69: Projected Points -> 11 points
# Group 70: Original Points -> 2 points
# Group 70: Projected Points -> 2 points
# Group 71: Original Points -> 6 points
# Group 71: Projected Points -> 6 points
# Group 72: Original Points -> 11 points
# Group 72: Projected Points -> 11 points
# Group 73: Original Points -> 23 points
# Group 73: Projected Points -> 23 points
# Group 74: Original Points -> 19 points
# Group 74: Projected Points -> 19 points
# Group 75: Original Points -> 3 points
# Group 75: Projected Points -> 3 points
# Group 76: Original Points -> 9 points
# Group 76: Projected Points -> 9 points
# Group 77: Original Points -> 12 points
# Group 77: Projected Points -> 12 points
# Group 78: Original Points -> 10 points
# Group 78: Projected Points -> 10 points
# Group 79: Original Points -> 5 points
# Group 79: Projected Points -> 5 points
# Group 80: Original Points -> 17 points
# Group 80: Projected Points -> 17 points
# Group 81: Original Points -> 4 points
# Group 81: Projected Points -> 4 points
# Group 82: Original Points -> 14 points
# Group 82: Projected Points -> 14 points
# Group 83: Original Points -> 6 points
# Group 83: Projected Points -> 6 points
# Group 84: Original Points -> 6 points
# Group 84: Projected Points -> 6 points
# Group 85: Original Points -> 3 points
# Group 85: Projected Points -> 3 points
# Group 86: Original Points -> 7 points
# Group 86: Projected Points -> 7 points
# Group 87: Original Points -> 11 points
# Group 87: Projected Points -> 11 points
# Group 88: Original Points -> 5 points
# Group 88: Projected Points -> 5 points
# Group 89: Original Points -> 5 points
# Group 89: Projected Points -> 5 points
# Group 90: Original Points -> 3 points
# Group 90: Projected Points -> 3 points
# Group 91: Original Points -> 12 points
# Group 91: Projected Points -> 12 points
# Group 92: Original Points -> 5 points
# Group 92: Projected Points -> 5 points
# Group 93: Original Points -> 8 points
# Group 93: Projected Points -> 8 points
# Group 94: Original Points -> 11 points
# Group 94: Projected Points -> 11 points
# Group 95: Original Points -> 7 points
# Group 95: Projected Points -> 7 points
# Group 96: Original Points -> 9 points
# Group 96: Projected Points -> 9 points
# Group 97: Original Points -> 3 points
# Group 97: Projected Points -> 3 points
# Group 98: Original Points -> 6 points
# Group 98: Projected Points -> 6 points
# Group 99: Original Points -> 11 points
# Group 99: Projected Points -> 11 points
# Group 100: Original Points -> 9 points
# Group 100: Projected Points -> 9 points
# Group 101: Original Points -> 13 points
# Group 101: Projected Points -> 13 points
# Group 102: Original Points -> 8 points
# Group 102: Projected Points -> 8 points
# Group 103: Original Points -> 3 points
# Group 103: Projected Points -> 3 points
# Group 104: Original Points -> 6 points
# Group 104: Projected Points -> 6 points
# Group 105: Original Points -> 7 points
# Group 105: Projected Points -> 7 points
# Group 106: Original Points -> 8 points
# Group 106: Projected Points -> 8 points
# Group 107: Original Points -> 9 points
# Group 107: Projected Points -> 9 points
# Group 108: Original Points -> 7 points
# Group 108: Projected Points -> 7 points
# Group 109: Original Points -> 7 points
# Group 109: Projected Points -> 7 points
# Group 110: Original Points -> 16 points
# Group 110: Projected Points -> 16 points
# Group 111: Original Points -> 15 points
# Group 111: Projected Points -> 15 points
# Group 112: Original Points -> 5 points
# Group 112: Projected Points -> 5 points
# Group 113: Original Points -> 8 points
# Group 113: Projected Points -> 8 points
# Group 114: Original Points -> 3 points
# Group 114: Projected Points -> 3 points
# Group 115: Original Points -> 22 points
# Group 115: Projected Points -> 22 points
# Group 116: Original Points -> 1 points
# Group 116: Projected Points -> 1 points
# Group 117: Original Points -> 21 points
# Group 117: Projected Points -> 21 points
# Group 118: Original Points -> 18 points
# Group 118: Projected Points -> 18 points
# Group 119: Original Points -> 7 points
# Group 119: Projected Points -> 7 points
# Group 120: Original Points -> 4 points
# Group 120: Projected Points -> 4 points
# Group 121: Original Points -> 10 points
# Group 121: Projected Points -> 10 points
# Group 122: Original Points -> 11 points
# Group 122: Projected Points -> 11 points
# Group 123: Original Points -> 11 points
# Group 123: Projected Points -> 11 points
# Group 124: Original Points -> 4 points
# Group 124: Projected Points -> 4 points
# Group 125: Original Points -> 19 points
# Group 125: Projected Points -> 19 points
# Group 126: Original Points -> 5 points
# Group 126: Projected Points -> 5 points
# Group 127: Original Points -> 13 points
# Group 127: Projected Points -> 13 points
# Group 128: Original Points -> 6 points
# Group 128: Projected Points -> 6 points
# Group 129: Original Points -> 9 points
# Group 129: Projected Points -> 9 points
# Group 130: Original Points -> 3 points
# Group 130: Projected Points -> 3 points
# Group 131: Original Points -> 21 points
# Group 131: Projected Points -> 21 points
# Group 132: Original Points -> 12 points
# Group 132: Projected Points -> 12 points
# Group 133: Original Points -> 13 points
# Group 133: Projected Points -> 13 points
# Group 134: Original Points -> 11 points
# Group 134: Projected Points -> 11 points
# Group 135: Original Points -> 8 points
# Group 135: Projected Points -> 8 points
# Group 136: Original Points -> 1 points
# Group 136: Projected Points -> 1 points
# Group 137: Original Points -> 12 points
# Group 137: Projected Points -> 12 points
# Group 138: Original Points -> 9 points
# Group 138: Projected Points -> 9 points
# Group 139: Original Points -> 12 points
# Group 139: Projected Points -> 12 points
# Group 140: Original Points -> 18 points
# Group 140: Projected Points -> 18 points
# Group 141: Original Points -> 14 points
# Group 141: Projected Points -> 14 points
# Group 142: Original Points -> 2 points
# Group 142: Projected Points -> 2 points
# Group 143: Original Points -> 11 points
# Group 143: Projected Points -> 11 points
# Group 144: Original Points -> 6 points
# Group 144: Projected Points -> 6 points
# Group 145: Original Points -> 4 points
# Group 145: Projected Points -> 4 points
# Group 146: Original Points -> 1 points
# Group 146: Projected Points -> 1 points
# Group 147: Original Points -> 7 points
# Group 147: Projected Points -> 7 points
# Group 148: Original Points -> 11 points
# Group 148: Projected Points -> 11 points
# Group 149: Original Points -> 5 points
# Group 149: Projected Points -> 5 points
# Group 150: Original Points -> 11 points
# Group 150: Projected Points -> 11 points
# Group 151: Original Points -> 10 points
# Group 151: Projected Points -> 10 points
# Group 152: Original Points -> 9 points
# Group 152: Projected Points -> 9 points
# Group 153: Original Points -> 5 points
# Group 153: Projected Points -> 5 points
# Group 154: Original Points -> 10 points
# Group 154: Projected Points -> 10 points
# Group 155: Original Points -> 17 points
# Group 155: Projected Points -> 17 points
# Group 156: Original Points -> 11 points
# Group 156: Projected Points -> 11 points
# Group 157: Original Points -> 7 points
# Group 157: Projected Points -> 7 points
# Group 158: Original Points -> 7 points
# Group 158: Projected Points -> 7 points
# Group 159: Original Points -> 7 points
# Group 159: Projected Points -> 7 points
# Group 160: Original Points -> 13 points
# Group 160: Projected Points -> 13 points
# Group 161: Original Points -> 16 points
# Group 161: Projected Points -> 16 points
# Group 162: Original Points -> 18 points
# Group 162: Projected Points -> 18 points
# Group 163: Original Points -> 5 points
# Group 163: Projected Points -> 5 points
# Group 164: Original Points -> 13 points
# Group 164: Projected Points -> 13 points
# Group 165: Original Points -> 6 points
# Group 165: Projected Points -> 6 points
# Group 166: Original Points -> 10 points
# Group 166: Projected Points -> 10 points
# Group 167: Original Points -> 7 points
# Group 167: Projected Points -> 7 points
# Group 168: Original Points -> 6 points
# Group 168: Projected Points -> 6 points
# Group 169: Original Points -> 11 points
# Group 169: Projected Points -> 11 points
# Group 170: Original Points -> 12 points
# Group 170: Projected Points -> 12 points
# Group 171: Original Points -> 1 points
# Group 171: Projected Points -> 1 points
# Group 172: Original Points -> 8 points
# Group 172: Projected Points -> 8 points
# Group 173: Original Points -> 9 points
# Group 173: Projected Points -> 9 points
# Group 174: Original Points -> 9 points
# Group 174: Projected Points -> 9 points
# Group 175: Original Points -> 21 points
# Group 175: Projected Points -> 21 points
# Group 176: Original Points -> 11 points
# Group 176: Projected Points -> 11 points
# Group 177: Original Points -> 14 points
# Group 177: Projected Points -> 14 points
# Group 178: Original Points -> 11 points
# Group 178: Projected Points -> 11 points
# Group 179: Original Points -> 12 points
# Group 179: Projected Points -> 12 points
# Group 180: Original Points -> 2 points
# Group 180: Projected Points -> 2 points
# Group 181: Original Points -> 10 points
# Group 181: Projected Points -> 10 points
# Group 182: Original Points -> 10 points
# Group 182: Projected Points -> 10 points
# Group 183: Original Points -> 6 points
# Group 183: Projected Points -> 6 points
# Group 184: Original Points -> 12 points
# Group 184: Projected Points -> 12 points
# Group 185: Original Points -> 15 points
# Group 185: Projected Points -> 15 points
# Group 186: Original Points -> 12 points
# Group 186: Projected Points -> 12 points
# Group 187: Original Points -> 9 points
# Group 187: Projected Points -> 9 points
# Group 188: Original Points -> 10 points
# Group 188: Projected Points -> 10 points
# Group 189: Original Points -> 3 points
# Group 189: Projected Points -> 3 points
# Group 190: Original Points -> 9 points
# Group 190: Projected Points -> 9 points
# Group 191: Original Points -> 11 points
# Group 191: Projected Points -> 11 points
# Group 192: Original Points -> 1 points
# Group 192: Projected Points -> 1 points
# Group 193: Original Points -> 3 points
# Group 193: Projected Points -> 3 points
# Group 194: Original Points -> 9 points
# Group 194: Projected Points -> 9 points
# Group 195: Original Points -> 8 points
# Group 195: Projected Points -> 8 points
# Group 196: Original Points -> 6 points
# Group 196: Projected Points -> 6 points
# Group 197: Original Points -> 9 points
# Group 197: Projected Points -> 9 points
# Group 198: Original Points -> 7 points
# Group 198: Projected Points -> 7 points
# Group 199: Original Points -> 11 points
# Group 199: Projected Points -> 11 points
# Group 200: Original Points -> 12 points
# Group 200: Projected Points -> 12 points
# Group 201: Original Points -> 13 points
# Group 201: Projected Points -> 13 points
# Group 202: Original Points -> 9 points
# Group 202: Projected Points -> 9 points
# Group 203: Original Points -> 8 points
# Group 203: Projected Points -> 8 points
# Group 204: Original Points -> 5 points
# Group 204: Projected Points -> 5 points
# Group 205: Original Points -> 1 points
# Group 205: Projected Points -> 1 points
# Group 206: Original Points -> 8 points
# Group 206: Projected Points -> 8 points
# Group 207: Original Points -> 7 points
# Group 207: Projected Points -> 7 points
# Group 208: Original Points -> 1 points
# Group 208: Projected Points -> 1 points
# Group 209: Original Points -> 2 points
# Group 209: Projected Points -> 2 points
# Group 210: Original Points -> 1 points
# Group 210: Projected Points -> 1 points
# Group 211: Original Points -> 1 points
# Group 211: Projected Points -> 1 points
# Group 212: Original Points -> 2 points
# Group 212: Projected Points -> 2 points
# Group 213: Original Points -> 3 points
# Group 213: Projected Points -> 3 points
# Group 214: Original Points -> 5 points
# Group 214: Projected Points -> 5 points
# Group 215: Original Points -> 3 points
# Group 215: Projected Points -> 3 points
# Group 216: Original Points -> 2 points
# Group 216: Projected Points -> 2 points
# Group 217: Original Points -> 4 points
# Group 217: Projected Points -> 4 points
